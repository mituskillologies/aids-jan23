# %%
x = 56
y = 44

# %%
print(x)
# Out:
# 56

# %%
print(y)
# Out:
# 44

# %%
num1 = 28
num_1 = 39

# %%
print(num1, num_1)
# Out:
# 28 39

# %%
Num1 = 30
num1 = 29

# %%
print(num1, Num1)
# Out:
# 29 30

# %%
pass1 = 34

# %%
num1 = 56
num1 = 23
num1 = 39
num1 = 28

# %%
num1
# Out:
# 28

# %%
num1 = 67.35

# %%
num1
# Out:
# 67.35

# %%
pass1
# Out:
# 34

# %%
num = 45

# %%
type(num)
# Out:
# int

# %%
num = 56.74

# %%
type(num)
# Out:
# float

# %%
num = 'Tushar'

# %%
type(num)
# Out:
# str

# %%
x = 5 + 7j

# %%
x
# Out:
# (5+7j)

# %%
num = 56

# %%
num * 123
# Out:
# 6888

# %%
num1 = 67 + 33
print(num1)
# Out:
# 100

# %%
num  = 34524255 ** 14252

# %%
num
# Out:
# ...

# %%
num1 = 34525.648262388834526626622

# %%
print(num1)
# Out:
# 34525.64826238884

# %%
num1 = 1234.5768e3

# %%
num1
# Out:
# 1234576.8

# %%
num1 = 1234.5768e-3
num1
# Out:
# 1.2345768

# %%
num1, num2, num3 = 78, 22, 39

# %%
print(num2, num3, num1)
# Out:
# 22 39 78

# %%
num2, num3, num1
# Out:
# (22, 39, 78)

# %%
num2 = num3 = num1 = 48

# %%
num2, num3, num1
# Out:
# (48, 48, 48)

# %%
num1, num2, num3 = 78, 22.24, 'Pune'

# %%
num2, num3, num1
# Out:
# (22.24, 'Pune', 78)

# %%
num1 = 34
num2 = 66
result = num1 + num2
print(result)
# Out:
# 100

# %%
num1 = 34; num2 = 66; result = num1 + num2; print(result)
# Out:
# 100

# %%
name = 'Tushar'

# %%
print(name)
# Out:
# Tushar

# %%
name = "Tushar"
print(name)
# Out:
# Tushar

# %%
num = '89'
print(num)
# Out:
# 89

# %%
num
# Out:
# '89'

# %%
print('I like Python programming')
# Out:
# I like Python programming

# %%
print("I like Python programming")
# Out:
# I like Python programming

# %%
print("I like 'Python' programming")
# Out:
# I like 'Python' programming

# %%
print('I like "Python" programming')
# Out:
# I like "Python" programming

# %%
data = 'hello@123'

# %%
data
# Out:
# 'hello@123'

# %%
name = 'Tushar'
city = 'Pune'

# %%
new = name + city
print(new)
# Out:
# TusharPune

# %%
new = name * 3
print(new)
# Out:
# TusharTusharTushar

# %%
new = (name + ' ') * 3
print(new)
# Out:
# Tushar Tushar Tushar

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello\nWorld')
# Out:
# Hello
# World

# %%
new = (name + '\n') * 3
print(new)
# Out:
# Tushar
# Tushar
# Tushar

# %%
print('Hello\tWorld')
# Out:
# Hello	World

# %%
print('Hello\bWorld')
# Out:
# World

# %%
print('Hello\\World')
# Out:
# Hello\World

# %%
print('Hello\'World')
# Out:
# Hello'World

# %%
print("Hello\"World")
# Out:
# Hello"World

# %%
# This is addition program
num1 = 34
num2 = 66
result = num1 + num2   # addition
print(result)
# Out:
# 100

# %%
# docstring or multi-line string
sent = '''Hello friends
How are you?
Welcome to Pune!'''

# %%
print(sent)
# Out:
# Hello friends
# How are you?
# Welcome to Pune!

# %%
'''This is addition program
Date: 21.01.2023
Author: Tushar B. Kute'''
num1 = 34
num2 = 66
result = num1 + num2   # addition
print(result)
# Out:
# 100

# %%
# String methods

# %%
name = 'Tushar'

# %%
name.lower()
# Out:
# 'tushar'

# %%
name.upper()
# Out:
# 'TUSHAR'

# %%
name.title()
# Out:
# 'Tushar'

# %%
name.swapcase()
# Out:
# 'tUSHAR'

# %%
name1 = 'Tushar'
name2 = 'Tushar123'
name3 = '12345'

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# False

# %%
name3.isdigit()
# Out:
# True

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name.startswith('T')
# Out:
# True

# %%
name.startswith('tu')
# Out:
# False

# %%
name.endswith('R')
# Out:
# False

# %%
name.endswith('ar')
# Out:
# True

# %%
name.replace('u','oo')
# Out:
# 'Tooshar'

# %%
ord('A')
# Out:
# 65

# %%
ord('y')
# Out:
# 121

# %%
ord('.')
# Out:
# 46

# %%
chr(93)
# Out:
# ']'

# %%
x = '\u0937'

# %%
x
# Out:
# 'ष'

# %%
name = 'तुषार कुटे'

# %%
print(name)
# Out:
# तुषार कुटे

# %%
name.startswith('तु')
# Out:
# True

# %%
name.endswith('टे')
# Out:
# True

# %%
ord('र')
# Out:
# 2352

# %%
chr(2352)
# Out:
# 'र'

# %%
len('तुषार')
# Out:
# 5

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
name = 'Tushar'
marks = 67.36
city = 'Pune'

# %%
# Basic print
print('My name is',name,'and marks are',marks)
# Out:
# My name is Tushar and marks are 67.36

# %%
# Formatted print
print('My name is %s and marks are %f' %(name,marks))
# Out:
# My name is Tushar and marks are 67.360000

# %%
print('My name is %s and marks are %i' %(name,marks))
# Out:
# My name is Tushar and marks are 67

# %%
print('My name is %s and marks are %.2f' %(name,marks))
# Out:
# My name is Tushar and marks are 67.36

# %%
print(name,marks,city)
# Out:
# Tushar 67.36 Pune

# %%
print(name,marks,city,sep='\t')
# Out:
# Tushar	67.36	Pune

# %%
print(name,marks,city,sep='\n')
# Out:
# Tushar
# 67.36
# Pune

# %% [markdown]
# ### Arithmetic Operators

# %%
num1 = 27
num2 = 5

# %%
result = num1 + num2
print(result)
# Out:
# 32

# %%
num1 - num2
# Out:
# 22

# %%
num1 * num2
# Out:
# 135

# %%
num1 / num2
# Out:
# 5.4

# %%
num1 // num2
# Out:
# 5

# %%
# Remainder of division
num1 % num2
# Out:
# 2

# %%
num1 ** num2
# Out:
# 14348907

# %% [markdown]
# ### Relational Operators

# %%
num1 > num2
# Out:
# True

# %%
num1 >= num2
# Out:
# True

# %%
num1 < num2
# Out:
# False

# %%
num1 <= num2
# Out:
# False

# %%
num1 == num2
# Out:
# False

# %%
num1 != num2
# Out:
# True

# %%
x = num1 > num2
print(x)
# Out:
# True

# %%
type(x)
# Out:
# bool

# %%
x = False

# %%
x
# Out:
# False

# %% [markdown]
# ### Assignment Operators

# %%
num1
# Out:
# 27

# %%
num1 += 2
print(num1)
# Out:
# 29

# %%
num1 -= 2     # num1 = num1 - 2
print(num1)
# Out:
# 27

# %% [markdown]
# ### Logical Operators

# %%
num1 > num2 and num1 < 100   # Both conditions should be true
# Out:
# True

# %%
num1 > num2 and num1 > 100
# Out:
# False

# %%
num1 > num2 or num1 > 100   # Anyone of them should be true
# Out:
# True

# %%
num1 < num2 or num1 > 100
# Out:
# False

# %%
num1 > num2
# Out:
# True

# %%
not num1 > num2  # Inverse the condition
# Out:
# False

# %% [markdown]
# ### Membership Selection

# %%
name = 'Tushar'
'u' in name    # Check to see if an element is present or not!
# Out:
# True

# %%
'S' in name
# Out:
# False

# %%
num = [6,5,3,2,5,4,7]
8 not in num
# Out:
# True

# %% [markdown]
# ### Precedence

# %%
num = 6 * 4 + 5 - 2 ** 2 * 4

# %%
num
# Out:
# 13

# %%
num = None

# %%
num

# %%
type(num)
# Out:
# NoneType

# %% [markdown]
# ### Type Conversion

# %%
# Implicit Type Conversion
num1 = 45
num2 = 55.89

result = num1 + num2

# %%
type(result)
# Out:
# float

# %%
# Explicit Type Conversion / Type Casting
result = num1 + int(num2)

# %%
type(result)
# Out:
# int

# %%
result
# Out:
# 100

# %%
num = '123'
num * 3
# Out:
# '123123123'

# %%
int(num) * 3
# Out:
# 369

# %%
name = 'Tushar'
marks = 65.89

# %%
password = name + marks
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-a5bc70c1ac19> in <module>
# ----> 1 password = name + marks
#
# TypeError: can only concatenate str (not "float") to str

# %%
password = name + str(marks)
password
# Out:
# 'Tushar65.89'

# %% [markdown]
# ### User Input

# %%
num = int(input('Enter the number:'))
# Out:
# Enter the number:45

# %%
num
# Out:
# 45

# %%
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
add = num1 + num2
print('Addition is:', add)
# Out:
# Enter first number:48
# Enter second number:52
# Addition is: 100
